# %%
# !pip install "tensorflow-cpu<2.16" "protobuf>=4.21.1,<5" -q

# %%
import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print("Data loaded:", x_train.shape, y_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Data loaded: (60000, 28, 28) (60000,)

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)
print("Preprocessing done")
# Out:
# Preprocessing done

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(784,)),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(
    optimizer=tf.keras.optimizers.SGD(learning_rate=0.05),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(x_train, y_train, epochs=3, batch_size=100, verbose=1)
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print("Accuracy:", test_accuracy)
# Out:
# Epoch 1/3
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 1s 624us/step - accuracy: 0.8360 - loss: 0.6705
# Epoch 2/3
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step - accuracy: 0.8898 - loss: 0.4085
# Epoch 3/3
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - accuracy: 0.8982 - loss: 0.3681
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - accuracy: 0.9084 - loss: 0.3382
# Accuracy: 0.9083999991416931
